# %% [markdown]
# <a href="https://colab.research.google.com/github/mutterer/enderscopy/blob/colab/00_colab_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q git+https://github.com/mutterer/enderscopy.git@colab
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
# !pip install -q ipympl

from google.colab import output
output.enable_custom_widget_manager()

# %matplotlib widget

# %%
import time
import matplotlib
from enderscope import SerialUtils, Stage, Panel
# connect to a virtual enderscope and create a stage object
s = Stage('virtual', 115200)
s.home
s.move_absolute(150,150)

# %%
p = Panel(s)
