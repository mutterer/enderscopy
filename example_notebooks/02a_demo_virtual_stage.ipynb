# %% [markdown]
# ## Enderscopy stage demo
# ### shows how to create a virtual enderscope stage

# %%
import time
from enderscope import SerialUtils, Stage, Panel
# connect to a virtual enderscope and create a stage object
# %matplotlib widget
s = Stage('virtual', 115200)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/miniforge3/envs/enderscope3/lib/python3.12/site-packages/matplotlib/backends/registry.py:407, in BackendRegistry.resolve_gui_or_backend(self, gui_or_backend)
#     406 try:
# --> 407     return self.resolve_backend(gui_or_backend)
#     408 except Exception:  # KeyError ?
#
# File ~/miniforge3/envs/enderscope3/lib/python3.12/site-packages/matplotlib/backends/registry.py:369, in BackendRegistry.resolve_backend(self, backend)
#     368 if gui is None:
# --> 369     raise RuntimeError(f"'{backend}' is not a recognised backend name")
#     371 return backend, gui if gui != "headless" else None
#
# RuntimeError: 'widget' is not a recognised backend name
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 4
#       1 import time
#       2 from enderscope import SerialUtils, Stage, Panel
#       3 # connect to a virtual enderscope and create a stage object
# ----> 4 get_ipython().run_line_magic('matplotlib', 'widget')
#       5 s = Stage('virtual', 115200)
#
# File ~/miniforge3/envs/enderscope3/lib/python3.12/site-packages/matplotlib/backends/registry.py:409, in BackendRegistry.resolve_gui_or_backend(self, gui_or_backend)
#     407     return self.resolve_backend(gui_or_backend)
#     408 except Exception:  # KeyError ?
# --> 409     raise RuntimeError(
#     410         f"'{gui_or_backend}' is not a recognised GUI loop or backend name")
#
# RuntimeError: 'widget' is not a recognised GUI loop or backend name

# %%
from enderscope import ScanPatterns
s.home()
origin = [25,200] # coordinates of first position
steps = [30,-25] # x and y shifts to next item
positions = ScanPatterns.snake(8,6) * steps + origin
for p in positions:
    s.move_position(p)

# %%
p = Panel(s)
# Out:
# GridspecLayout(children=(Button(description='Up', layout=Layout(grid_area='widget001', height='auto', width='a…
# Output()

# %%
s.move_position([100,200,100])
